# %% [markdown]
# <a href="https://colab.research.google.com/github/pranshurastogi29/clustering-the-palsy/blob/master/stat_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats

df = pd.read_csv('/content/drive/My Drive/cpi.csv')

# %%
from math import sqrt
from numpy.random import seed
from numpy.random import randn
from numpy import mean
from scipy.stats import sem
from scipy.stats import t
 
# function for calculating the t-test for two independent samples
def independent_ttest(data1, data2, alpha):
	# calculate means
	mean1, mean2 = mean(data1), mean(data2)
	# calculate standard errors
	se1, se2 = sem(data1), sem(data2)
	# standard error on the difference between the samples
	sed = sqrt(se1**2.0 + se2**2.0)
	# calculate the t statistic
	t_stat = (mean1 - mean2) / sed
	# degrees of freedom
	df = len(data1) + len(data2) - 2
	# calculate the critical value
	cv = t.ppf(1.0 - alpha, df)
	# calculate the p-value
	p = (1.0 - t.cdf(abs(t_stat), df)) * 2.0
	# return everything
	return t_stat, df, cv, p
 
# seed the random number generator
seed(1)
# generate two independent samples
# calculate the t test
d,l = [],[]
for i in df.columns:
  for j in df.columns:
    data1 = df[i].values
    data2 = df[j].values
    alpha = 0.05
    print(i,j)
    t_stat, p = stats.ttest_ind(data1, data2, equal_var = False)
    print('t=%.3f, p=%.3f' % (t_stat, p))
    if p > alpha:
	    print('ACCEPT null hypothesis that the means are equal.')
    else:
	    print('REJECT the null hypothesis that the means are equal.')
    l.append(t_stat)
  d.append(l)
  l = []
d = np.array(d)
# Out:
# fcmeans fcmeans
# t=0.000, p=1.000
# ACCEPT null hypothesis that the means are equal.
# fcmeans kmeans
# t=2.519, p=0.017
# REJECT the null hypothesis that the means are equal.
# fcmeans cso_km
# t=11.800, p=0.000
# REJECT the null hypothesis that the means are equal.
# fcmeans cso_fm
# t=9.754, p=0.000
# REJECT the null hypothesis that the means are equal.
# fcmeans g_cso_km
# t=13.029, p=0.000
# REJECT the null hypothesis that the means are equal.
# fcmeans g_cso_fm
# t=6.867, p=0.000
# REJECT the null hypothesis that the means are equal.
# fcmeans cn_pso
# t=0.770, p=0.448
# ACCEPT null hypothesis that the means are equal.
# fcmeans cn_pso_km
# t=0.411, p=0.687
# ACCEPT null hypothesis that the means are equal.
# fcmeans cn_pso_fm
# t=0.495, p=0.628
# ACCEPT null hypothesis that the means are equal.
# fcmeans hpso_km
# t=0.495, p=0.628
# ACCEPT null hypothesis that the means are equal.
# fcmeans hpso_fm
# t=0.495, p=0.628
# ACCEPT null hypothesis that the means are equal.
# ...

# %%
df_t_test = pd.DataFrame(d)
df_t_test.columns = df.columns
df_t_test.index = df.columns
df_t_test = df_t_test.fillna(0)
df_t_test
# Out:
#              fcmeans     kmeans     cso_km  ...  cn_pso_fm    hpso_km    hpso_fm
# fcmeans     0.000000   2.518974  11.799624  ...   0.494984   0.494984   0.494984
# kmeans     -2.518974   0.000000   9.327158  ...  -3.078349  -3.078349  -3.078349
# cso_km    -11.799624  -9.327158   0.000000  ... -16.213674 -16.213674 -16.213674
# cso_fm     -9.753641  -7.570885   0.616670  ... -12.066330 -12.066330 -12.066330
# g_cso_km  -13.029470 -10.268493   0.196762  ... -20.771509 -20.771509 -20.771509
# g_cso_fm   -6.866782  -4.884690   2.507608  ...  -7.967977  -7.967977  -7.967977
# cn_pso     -0.770280   2.254490  13.401172  ...  -0.662266  -0.662266  -0.662266
# cn_pso_km  -0.411090   3.150662  16.240922  ...   1.000000   1.000000   1.000000
# cn_pso_fm  -0.494984   3.078349  16.213674  ...   0.000000   0.000000   0.000000
# hpso_km    -0.494984   3.078349  16.213674  ...   0.000000   0.000000   0.000000
# hpso_fm    -0.494984   3.078349  16.213674  ...   0.000000   0.000000   0.000000
#
# ...

# %%
d,l = [],[]
for i in df.columns:
  for j in df.columns:
    data1 = df[i].values
    data2 = df[j].values
    alpha = 0.05
    t_stat, p = stats.ttest_ind(data1, data2, equal_var = False)
    l.append(p)
  d.append(l)
  l = []
d = np.array(d)
df_pval = pd.DataFrame(d)
df_pval.columns = df.columns
df_pval.index = df.columns
df_pval = df_pval.fillna(0)
df_pval
# Out:
#                 fcmeans        kmeans  ...       hpso_km       hpso_fm
# fcmeans    1.000000e+00  1.733302e-02  ...  6.277832e-01  6.277832e-01
# kmeans     1.733302e-02  1.000000e+00  ...  7.647997e-03  7.647997e-03
# cso_km     8.490121e-13  2.259057e-10  ...  6.441414e-11  6.441414e-11
# cso_fm     1.363312e-10  2.721136e-08  ...  4.008884e-09  4.008884e-09
# g_cso_km   1.968314e-13  4.915958e-11  ...  1.821989e-12  1.821989e-12
# g_cso_fm   2.503759e-07  4.425836e-05  ...  9.046644e-07  9.046644e-07
# cn_pso     4.483192e-01  3.308543e-02  ...  5.178472e-01  5.178472e-01
# cn_pso_km  6.867423e-01  6.506586e-03  ...  3.331701e-01  3.331701e-01
# cn_pso_fm  6.277832e-01  7.647997e-03  ...  0.000000e+00  0.000000e+00
# hpso_km    6.277832e-01  7.647997e-03  ...  0.000000e+00  0.000000e+00
# hpso_fm    6.277832e-01  7.647997e-03  ...  0.000000e+00  0.000000e+00
#
# [11 rows x 11 columns]
